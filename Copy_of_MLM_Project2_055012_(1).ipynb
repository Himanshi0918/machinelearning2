# %% [markdown]
# <a href="https://colab.research.google.com/github/AayushGarg001/MLM-Project-2_Supervised-Learning/blob/main/MLM_Project2_055001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Supervised Learning Models on Import-Export Dataset using Python**
#
#
#
# ---
#
#
#
# ## **PROJECT CONTENTS:**
# - Project Information
# - Description of Data
# - Data Sampling
# - Project Objectives | Problem Statements
# - Analysis of Data
# - Observations | Findings
# - Managerial Insights | Recommendations
#
# ---
#
# ### **1. Project Information**
# - **Title**: Data Exploration with Python using Pandas & Numpy Libraries
# - **Student**: Himanshi Sharma (055012)
#
# ---
#
# ### **2. Description of Data**
# - **Data Source**: https://www.kaggle.com/datasets/chakilamvishwas/imports-exports-15000
#
#   A live link is used in the dataset
#
# - **Data Columns Description**:
#   - **Transaction_ID**: Unique identifier for each trade transaction.
#   - **Country**: Country of origin or destination for the trade.
#   - **Product**: Product being traded.
#   - **Import_Export**: Indicates whether the transaction is an import or export.
#   - **Quantity**: Amount of the product traded.
#   - **Value**: Monetary value of the product in USD.
#   - **Date**: Date of the transaction.
#   - **Category**: Category of the product (e.g., Electronics, Clothing, Machinery).
#   - **Port**: Port of entry or departure.
#   - **Customs_Code**: Customs or HS code for product classification.
#   - **Weight**: Weight of the product in kilograms.
#   - **Shipping_Method**: Method used for shipping (e.g., Air, Sea, Land).
#   - **Supplier**: Name of the supplier or manufacturer.
#   - **Customer**: Name of the customer or recipient.
#   - **Invoice_Number**: Unique invoice number for the transaction.
#   - **Payment_Terms**: Terms of payment (e.g., Net 30, Net 60, Cash on Delivery).
#
# - **Data Type**: Since the dataset contains multiple entities (countries) and records data over time, this is an example of Panel Data (also called longitudinal data).
#
# - **Data Variables**:
#   - **All non-null Variables**
#     - **Numbers**:
#       - Integer Variables: 3 (Quantity, Customs_Code, Invoice_Number)
#       - Float (Decimal) Variables: 2 (Value, Weight)
#     - **Text**: 9 (Country, Product, Import_Export, Category, Port, Shipping_Method, Supplier, Customer, Payment_Terms)
#     - **DateTime**: 1 (Date)
#
# ---
#
# ### **3. Data Sampling**
# From the dataset containing 15,000 values, a sample of 5001 entries was taken. The dataset sample (now referred to as `hs12_sample`) was taken into account for further exploration.
#
# - **Data Variables**:
#   - **Index Variables**: 'Transaction_ID', 'Invoice_Number'
#   - **Categorical Variables**:
#     - Nominal Variables: Country, Product, Import_Export, Category, Port, Shipping_Method, Supplier, Customs_Code, Customer
#     - Ordinal Variable: Payment_Terms
#   - **Non-Categorical Variables**: Quantity, Value, and Weight
#
# ---
#
# ### **4. Project Objectives**
# - Classification of Dataset into {Segments | Clusters | Classes} using Supervised Learning Classification Algorithms
# - Identification of {Important | Contributing | Significant} Variables or Features and their Thresholds for Classification
# - Determination of an appropriate Classification Model based on Performance Metrics
#
#
# ---
#
# ### **5. Exploratory Data Analysis**
# #### **5.1. Data Preprocessing:**
# - The data has no missing values, hence no missing data treatment was performed.
# - For Encoding, **Ordinal Encoder** was used.
# - For Scaling, **Min-Max Scaler** was used.
#
# #### **5.2. Descriptive Statistics**
# - **Non-Categorical Variables**:
#   - Measures of Central Tendency: Minimum, Maximum, Mean, Median, Mode, Percentile
#   - Measures of Dispersion: Range, Standard Deviation, Skewness, Kurtosis, Correlation (Matrix)
#   - Composite Measure: Coefficient of Variation, Confidence Interval
#
# - **Categorical Variables**:
#   - Count, Frequency, Proportion, Minimum, Maximum, Mode, Rank
#
# #### **5.3. Data Visualization**
# - Various subplots were used such as Bar, Heatmaps, Histograms, and Correlation Matrices.
#
# #### **5.4. Inferential Statistics**
# - **Categorical Variable** (Nominal | Ordinal):
#   - Test of Homogeneity (Chi-sq)
# - **Non-Categorical Variable**:
#   - Test of Normality (Shapiro-Wilk, Kolmogorov-Smirnov, Anderson-Darling, Jarque-Bera)
#   - Test of Correlation (t)
#
# #### **5.5. Machine Learning Models**
#
# - **Logistic Regression (LR)**:
#   Logistic regression is a classification algorithm that models the probability of a binary outcome based on one or more predictor variables using a logistic function.
#
# - **Support Vector Machines (SVM)**:
#   SVM finds a hyperplane that best separates the data into classes by maximizing the margin between the closest points of the classes (support vectors).
#
# - **Stochastic Gradient Descent (SGD)**:
#   An iterative optimization algorithm used for minimizing loss functions in linear classifiers and regressors, particularly useful for large datasets.
#
# - **Decision Trees**:
#   A tree-based algorithm where each internal node represents a decision on a feature, each leaf node represents an outcome, and paths from root to leaf represent classification rules.
#
# - **K-Nearest Neighbors (KNN)**:
#   A lazy learning algorithm that classifies a data point based on the majority class of its k-nearest neighbors in the feature space.
#
# - **Naive Bayes (NB)**:
#   A probabilistic classifier based on Bayes' theorem, assuming strong independence between features.
#
# - **Bagging (Bootstrap Aggregating)**:
#   Combines predictions from multiple models (e.g., Random Forest) to reduce variance and improve accuracy.
#
# - **Boosting**:
#   Combines weak learners sequentially to form a strong learner by minimizing errors iteratively (e.g., Extreme Gradient Boosting - XGBoost).
#
# #### **5.6. Model Performance Metrics**
#
# - **Confusion Matrix**:
#   - Sensitivity (Recall): True Positive Rate
#   - Specificity: True Negative Rate
#   - Accuracy: Overall correctness
#   - Precision: Positive Predictive Value
#   - F1-Score: Harmonic mean of Precision and Recall
#   - AUC: Area Under the ROC Curve
#
# - **K-Fold Cross-Validation**: Splits data into k subsets; trains on k-1 and tests on the remaining one iteratively to ensure robust performance evaluation.
#
# - **Model Run Statistics**:
#   - Time Taken
#   - Memory Used
#   - Inherent Complexity
# ---
#
#
# ### **6. Observations and Findings**
#
# #### **6.1. Nature of Data**
# - **Missing Data**: The dataset contained no missing values.
# - **Non-Numeric Categorical Data**: Categorical variables (e.g., Country, Product) were encoded using ordinal encoding.
# - **Scales and Outliers**:
#   - Non-categorical numeric data (Quantity, Value, Weight) were scaled using Min-Max scaling.
#   - Box plots revealed potential outliers, but they were not removed as they might hold valuable information.
#
# #### **6.2. Supervised Machine Learning**
#
#
#
#
#
#
# **1. Logistic Regression (LR) vs. Support Vector Machine (SVM)**
#
# **Performance Metrics:**
#
# | Model            | Accuracy | Macro Avg F1-score | Weighted Avg F1-score |
# |------------------|----------|--------------------|----------------------|
# | Logistic Regression | 0.33    | 0.31             | 0.31               |
# | SVM               | 0.33    | 0.27             | 0.26               |
#
# LR and SVM showed similar overall accuracy, around 33%. However, LR achieved slightly better F1-scores, both macro and weighted, indicating a marginally better balance between precision and recall across classes. SVM struggled particularly with Class 0.0, showing 0 precision, recall, and F1-score for that class.
#
# **Run Statistics:**
#
# | Model            | Runtime (seconds) |
# |------------------|-------------------|
# | Logistic Regression | 0.0148           |
# | SVM               | 0.7553           |
#
# LR was significantly faster than SVM, with a runtime of 0.0148 seconds compared to 0.7553 seconds for SVM. This difference in runtime can be crucial, especially for larger datasets or applications where speed is important.
#
# **Conclusion:**
#
# While both LR and SVM achieved similar accuracy, LR is preferred for this dataset due to its faster runtime and slightly better overall performance across classes, as indicated by the F1-scores. SVM's significantly longer runtime and poor performance on Class 0.0 make it less suitable for this specific task.
#
# **2. Decision Tree (DT) vs. K-Nearest Neighbors (KNN)**
#
# **Performance Metrics:**
#
# | Model            | Accuracy | Macro Avg F1-score | Weighted Avg F1-score |
# |------------------|----------|--------------------|----------------------|
# | Decision Tree    | 0.35    | 0.35             | 0.35               |
# | KNN               | 0.34    | 0.31             | 0.31               |
#
# DT achieved slightly higher accuracy (35%) compared to KNN (34%). DT also showed better overall performance across classes, as indicated by higher macro and weighted average F1-scores.
#
# **Run Statistics:**
#
# | Model            | Runtime (seconds) |
# |------------------|-------------------|
# | Decision Tree    | 0.0321           |
# | KNN               | 0.0062           |
#
# KNN was significantly faster than DT, with a runtime of 0.0062 seconds compared to 0.0321 seconds for DT. This difference in runtime might be important for applications where speed is prioritized.
#
# **Conclusion:**
#
# Although KNN was faster, DT is preferred for this dataset due to its slightly higher accuracy and better overall performance across classes. However, if runtime is a critical constraint, KNN might be a viable alternative, especially for smaller datasets.
#
# **3. Logistic Regression (LR) vs. Decision Tree (DT)**
#
# **Performance Metrics:**
#
# | Model            | Accuracy | Macro Avg F1-score | Weighted Avg F1-score |
# |------------------|----------|--------------------|----------------------|
# | Logistic Regression | 0.33    | 0.31             | 0.31               |
# | Decision Tree    | 0.35    | 0.35             | 0.35               |
#
# DT achieved higher accuracy (35%) compared to LR (33%). DT also showed better overall performance across classes, as indicated by higher macro and weighted average F1-scores.
#
# **Run Statistics:**
#
# | Model            | Runtime (seconds) |
# |------------------|-------------------|
# | Logistic Regression | 0.0148           |
# | Decision Tree    | 0.0321           |
#
# LR was slightly faster than DT, with a runtime of 0.0148 seconds compared to 0.0321 seconds for DT. This difference in runtime might be relevant for very large datasets or applications with strict time constraints.
#
# **Conclusion:**
#
# Despite the slightly faster runtime of LR, DT is favored for this dataset due to its higher accuracy and better overall performance across classes. However, LR remains a viable option for quick analysis and interpretability, especially when runtime is a major concern.
#
# **4. Decision Tree (DT) vs. Random Forest (RF)**
#
# **Performance Metrics:**
#
# | Model            | Accuracy | Macro Avg F1-score | Weighted Avg F1-score |
# |------------------|----------|--------------------|----------------------|
# | Decision Tree    | 0.35    | 0.35             | 0.35               |
# | Random Forest    | 0.35    | 0.34             | 0.34               |
#
# DT and RF showed very similar accuracy, around 35%. DT had slightly better macro and weighted average F1-scores.
#
# **Run Statistics:**
#
# | Model            | Runtime (seconds) |
# |------------------|-------------------|
# | Decision Tree    | 0.0321           |
# | Random Forest    | 1.4696           |
#
# DT was significantly faster than RF, with a runtime of 0.0321 seconds compared to 1.4696 seconds for RF. This difference in runtime can be substantial, especially for larger datasets or iterative model development.
#
# **Conclusion:**
#
# While both models achieved similar accuracy, DT is preferred for this dataset due to its much faster runtime and marginally better overall performance across classes, as indicated by the F1-scores. RF's significantly longer runtime makes it less practical for this specific task unless higher accuracy is absolutely critical and runtime is not a major constraint.
#
#
#
# ---
#
#
#
# #### **Cross-Validation of Results and Performance**
#
#
# **1. Logistic Regression (LR)**
#
# * Mean Cross-Validation Accuracy: 0.3434
# * Test Set Accuracy: 0.33
#
# **Observations:**
# * The cross-validation accuracy is slightly higher than the test set accuracy, suggesting a slight overfitting to the training data.
# * The model struggles with overall accuracy, indicating potential challenges in capturing complex relationships or class imbalances.
# * It might show better recall for certain classes while performing poorly on others, highlighting potential biases.
#
# **2. Support Vector Machine (SVM)**
#
# * Mean Cross-Validation Accuracy: 0.3383
# * Test Set Accuracy: 0.33
#
# **Observations:**
# * The cross-validation and test set accuracies are very similar, indicating good generalization performance.
# * The model exhibits a strong bias towards predicting certain classes, achieving high recall for some but failing completely for others.
# * This behavior might be due to class imbalance or the model's sensitivity to specific data points.
#
# **3. Decision Tree (DT)**
#
# * Mean Cross-Validation Accuracy: 0.3434
# * Test Set Accuracy: 0.35
#
# **Observations:**
# * The test set accuracy is slightly higher than the cross-validation accuracy, suggesting good generalization and potentially even slight underfitting.
# * The model shows consistent performance across classes, with slight improvements in precision, recall, and F1-score for certain classes.
# * This indicates DT's ability to capture non-linear relationships better than LR and SVM.
#
# **4. Random Forest (RF)**
#
# * Mean Cross-Validation Accuracy: 0.3383
# * Test Set Accuracy: 0.35
#
# **Observations:**
# * The test set accuracy is slightly higher than the cross-validation accuracy, indicating good generalization performance.
# * The performance is similar to DT, but with potentially higher memory usage and runtime, making it less practical for this dataset if runtime is critical.
# * RF might be more effective for larger and more complex datasets where its ensemble approach can reduce overfitting.
#
#
# ---
#
# ### **7. Managerial Insights and Recommendations**
#
# #### **7.1. Preprocessing of Data**
# - **Missing Data**: No specific treatment is necessary due to the absence of missing data.
# - **Encoding**: Ordinal encoding proved effective for categorical variables.
# - **Scaling**: Min-Max scaling was appropriate to address potential scale differences.
# - **Data Split**: A **70:30 split** for training and testing sets would be appropriate for future supervised learning tasks.
#
# #### **7.2. Supervised Machine Learning**
#
#
# #### **Inference regarding the Purpose of Classification**
# The purpose of the classification is to identify patterns in the data and accurately assign instances to predefined classes. However, all models struggled with poor overall accuracy, suggesting challenges such as class imbalance, insufficient data quality, or lack of relevant features. Improving these areas is critical for achieving meaningful insights.
#
# ---
#
# #### **Logistic Regression (LR)**
# #### **Key Features and Thresholds**
# - Focus on highly correlated features for interpretability, e.g., categorical variables or numeric predictors with strong linear relationships.
# - **Threshold:** Evaluate multiple decision thresholds (e.g., 0.5, 0.6) to balance precision and recall, particularly for underrepresented classes.
#
# #### **Insight on Uniqueness, Usability, and Suitability**
# - **Uniqueness:** Simple and interpretable; suitable for datasets with linearly separable classes.
# - **Usability:** Best for quick preliminary analysis and insights, especially when time and interpretability are critical.
# - **Suitability:** Limited by poor performance in non-linear relationships and class imbalance. More effective with balanced and linearly distributed datasets.
#
# ---
#
# #### **Support Vector Machine (SVM)**
# #### **Key Features and Thresholds**
# - Focus on features that enhance separability between classes in a high-dimensional space.
# - **Threshold:** Use a soft margin for hyperparameter tuning to balance precision and recall for minority classes.
#
# #### **Insight on Uniqueness, Usability, and Suitability**
# - **Uniqueness:** Excellent at capturing complex decision boundaries, especially with kernel tricks for non-linear relationships.
# - **Usability:** Less interpretable and computationally expensive; more suited to small, high-dimensional datasets.
# - **Suitability:** Performs poorly on imbalanced datasets. Best for situations where capturing subtle patterns is essential.
#
# ---
#
# #### **Decision Tree (DT)**
# #### **Key Features and Thresholds**
# - Select features with high information gain or Gini index for splitting nodes.
# - **Threshold:** Adjust tree depth to avoid overfitting while maintaining interpretability (e.g., max depth of 5).
#
# #### **Insight on Uniqueness, Usability, and Suitability**
# - **Uniqueness:** Provides interpretable, tree-structured decisions, capturing non-linear relationships effectively.
# - **Usability:** Easy to visualize and explain, making it useful for decision-making.
# - **Suitability:** Suitable for moderately complex datasets but prone to overfitting on small datasets. Effective for balanced and moderately imbalanced data.
#
# ---
#
# #### **Random Forest (RF)**
# #### **Key Features and Thresholds**
# - Use ensemble averaging to improve predictive accuracy and reduce variance.
# - **Threshold:** Focus on selecting the optimal number of trees (e.g., 50–100) and features per split for performance without excessive resource consumption.
#
# #### **Insight on Uniqueness, Usability, and Suitability**
# - **Uniqueness:** Combines multiple decision trees to improve stability and generalization, reducing overfitting compared to DT.
# - **Usability:** Higher computational cost and memory usage compared to DT but handles noisy and imbalanced data better.
# - **Suitability:** Ideal for larger datasets with complex relationships, where interpretability is less critical than predictive accuracy.
#
# ---
#
# ### **Recommendations for Managerial Actions**
# 1. **Data Quality and Balance:**
#    - Address class imbalance and improve feature engineering to enhance model performance.
#    - Consider oversampling, undersampling, or using class-weight adjustments.
#
# 2. **Model Selection:**
#    - **Logistic Regression** for fast, interpretable results where linear relationships dominate.
#    - **Decision Tree** for interpretable, non-linear modeling of moderately complex data.
#    - **Support Vector Machine** when high-dimensional data and non-linear patterns are present but computational efficiency is secondary.
#    - **Random Forest** for robust predictions in large, complex datasets.
#
# 3. **Operational Use:**
#    - Select models based on the trade-off between accuracy, runtime, and interpretability, aligning with project objectives and data constraints.
#
#
# ---
# ### **Identification of Important Variables or Features and Their Thresholds**
#
# #### **1. Key Features Identified from Multiple Models**
# Analyzing outputs from Decision Tree, Random Forest, XGBoost, KNN, Naive Bayes, and Logistic Regression reveals crucial insights into features influencing classification or clustering. Despite moderate accuracy across models, certain variables consistently emerge as significant:
#
# - **Country**
#   - Strongly correlates with trade patterns and economic agreements. Specific countries often dominate imports or exports in particular categories.
#   - **Thresholds**: Major trade partners (e.g., based on transaction counts or values) often form distinct groups influencing cluster formation.
#
# - **Product**
#   - Plays a pivotal role due to trade specialization, such as Electronics and Machinery versus Clothing.
#   - **Thresholds**: Products with high weights or values tend to indicate distinct classes or clusters.
#
# - **Import_Export**
#   - Differentiates transaction types and highlights trade flow distinctions.
#   - **Thresholds**: Exports are generally associated with higher-value products compared to imports in this dataset.
#
# - **Quantity, Value, and Total_Value**
#   - High numerical correlation with trade significance, particularly in models like Decision Tree and Random Forest.
#   - **Thresholds**:
#     - **Quantity**: Higher quantities are linked to lower-value items like raw materials or bulk goods.
#     - **Value**: Higher-value products cluster separately due to their economic significance.
#
# - **Weight**
#   - Critical for clustering based on shipping and logistics costs.
#   - **Thresholds**: Lightweight, high-value items (e.g., electronics) cluster distinctly from heavy, low-value items (e.g., raw metals).
#
# - **Shipping_Method**
#   - Reflects trade-specific preferences, such as air for lightweight, high-value items versus sea or land for bulk or low-value goods.
#   - **Thresholds**: Specific clusters align with shipping modes, such as air freight for electronics.
#
# - **Port**
#   - Ports often specialize in handling certain categories or trade flows.
#   - **Thresholds**: High-traffic ports typically align with distinct clusters.
#
# - **Customs_Code**
#   - Provides a categorical classification of goods, significantly impacting model performance.
#   - **Thresholds**: HS codes differentiate goods by economic sector or trade priority.
#
# ---
# ### **2.Key Takeaways for Stakeholders**
#
# 1. **Retention Strategies:**
#
# * **Problem:** Customers with low credit scores or low balances are more likely to churn.
# * **Action:** Develop tailored financial products or support services for these groups, such as personalized credit improvement plans or balance-building incentives.
#
# 2. **Revenue Growth:**
#
# * **Problem:** High-value customers are not being uniquely engaged.
# * **Action:** Create exclusive loyalty programs or targeted upsell campaigns for high-value segments (e.g., frequent buyers or high-salary earners).
#
# 3. **Customer Experience Enhancements:**
#
# * **Problem:** Some clusters represent customers who feel disconnected (e.g., inactive members).
#
# * **Action:** Launch re-engagement campaigns or survey these groups to understand and address their pain points.
#
# ### **Future Actions for the Company**
#
# 1. **Leverage Predictive Models:**
#
# * Automate the identification of high-risk customers using the classification model.
# * Implement early-warning systems to flag customers likely to churn, enabling intervention before it's too late.
#
# 2. **Personalized Marketing:**
#
# * Segment customers into the identified clusters and craft specific campaigns for each group.
#
#   Example: Offer discounts or loyalty rewards for segments that show signs of disengagement.
#
# 3. **Operational Changes:**
#
# * Enhance customer service for at-risk groups by assigning dedicated account managers.
# * Educate and empower frontline staff to use insights from these models to build stronger customer relationships.
#
# 4. **Measure & Iterate:**
#
# * Regularly track the performance of these strategies using KPIs such as churn rate, customer lifetime value, and retention rate.
# * Continue to refine models as more data becomes available.
#
# ### **Message to Stakeholders**
#
# * **For Executives:** This analysis aligns directly with business goals by reducing churn, increasing revenue, and improving customer satisfaction.
# * **For Marketing Teams:** The identified customer clusters provide clear directions for targeted campaigns, maximizing ROI.
# * **For Operations Teams:** The actionable insights offer a pathway to optimize customer interactions and enhance service levels.
#
# **The Future of Decision-Making**
#
# This report is the foundation for a data-driven culture where decisions are based on customer insights. By implementing the recommended strategies and integrating predictive tools into daily operations, the company will:
#
# 1. Retain more customers, reducing costs associated with acquiring new ones.
# 2. Enhance customer loyalty, translating to higher lifetime value.
# 3. Gain a competitive advantage through personalized and proactive engagement strategies.
#
# -----------------------------------------------------------
#
# #### **3. Model-Specific Observations and Insights**
#
#
# **1. Decision Tree (DT)**
#
# * Accuracy: 35% (low)
# * Key Variables: Country, Product, Quantity, and Value consistently influence tree splits, indicating their importance in classification.
# * Misclassifications: Significant confusion between Cluster 0 and Cluster 1, suggesting potential overlap or difficulty in distinguishing these classes. Slightly better performance for Class 2.0, indicating stronger performance in distinguishing specific clusters.
# * Thresholds: Products with higher Value and lower Weight are more accurately identified. Quantity thresholds help differentiate bulk from specialized goods.
# * Insights: DT provides interpretable, tree-structured decisions, capturing non-linear relationships effectively. It's easy to visualize and explain, making it useful for decision-making. However, it might be prone to overfitting on small datasets.
#
# **2. Random Forest (RF)**
#
# * Accuracy: 35% (low)
# * Key Variables: Similar to Decision Tree, with enhanced handling of non-linear relationships due to ensemble averaging. Features like Port and Customs_Code significantly influence predictions.
# * Insights: RF combines multiple decision trees to improve stability and generalization, reducing overfitting compared to DT. It handles noisy and imbalanced data better. However, it has higher computational cost and memory usage compared to DT.
#
# **3. XGBoost**
#
# * Accuracy: 33% (low)
# * Key Variables: Product, Country, and Value are prominent based on feature importance scores.
# * Insights: Performance suffers from imbalanced data. Adjusting thresholds for major features like Value or using sampling techniques could improve results.
#
# **4. KNN**
#
# * Accuracy: 34% (low)
# * Key Variables: Quantity and Weight, as KNN relies heavily on distance-based relationships.
# * Insights: Normalizing data could enhance clustering based on these variables. KNN is a lazy learning algorithm that classifies a data point based on the majority class of its k-nearest neighbors in the feature space.
#
# **5. Naive Bayes (NB)**
#
# * Accuracy: 33% (low)
# * Key Variables: Import_Export, Customs_Code, and Shipping_Method.
# * Insights: Assumes feature independence, yet categorical variables like Import_Export and Customs_Code drive predictions. This model is a probabilistic classifier based on Bayes' theorem, assuming strong independence between features.
#
# **6. Logistic Regression (LR)**
#
# * Accuracy: 33% (low)
# * Key Variables: Country, Product, and Shipping_Method.
# * Insights: Struggles significantly with Cluster 1 due to class imbalance or overlapping data. Refining thresholds for categorical features like Shipping_Method may help separate clusters. Logistic regression is a classification algorithm that models the probability of a binary outcome based on one or more predictor variables using a logistic function.
#
# **7. Support Vector Machine (SVM)**
#
# * Accuracy: 33% (low)
# * Key Variables: Features that enhance separability between classes in a high-dimensional space.
# * Insights: Excellent at capturing complex decision boundaries, especially with kernel tricks for non-linear relationships. Less interpretable and computationally expensive; more suited to small, high-dimensional datasets. Performs poorly on imbalanced datasets. Best for situations where capturing subtle patterns is essential.

# %% [markdown]
# ##**Project Information and Analysis**

# %%
# Import Relevant Python Libraries

from io import StringIO
import requests
import pandas as pd
import statsmodels.formula.api as sm
from scipy.stats import chi2_contingency
from scipy.stats import shapiro, kstest, anderson, jarque_bera
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, DBSCAN, Birch
from scipy.cluster.hierarchy import dendrogram, linkage
import statsmodels.stats.descriptivestats as dstats
import numpy as np  # For Data Manipulation
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder  # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.impute import SimpleImputer, KNNImputer  # For Imputation of Missing Data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler  # For Rescaling Data
from sklearn.model_selection import train_test_split  # For Splitting Data into Training & Testing Sets
import matplotlib.pyplot as plt
import seaborn as sns  # For Data Visualization
import scipy.cluster.hierarchy as sch  # For Hierarchical Clustering
from sklearn.cluster import AgglomerativeClustering as agclus, KMeans as kmclus  # For Agglomerative & K-Means Clustering
from sklearn.metrics import silhouette_score,davies_bouldin_score  # For Clustering Model Evaluation
import statsmodels.api as sm
from sklearn import metrics
import scipy.stats as stats
import statsmodels.stats.multicomp as multi
import warnings
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.model_selection import KFold, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score



warnings.filterwarnings('ignore')

# %%
import gdown
import pandas as pd

# Google Drive file ID
file_id = '1-KectG9Ye8Zy-Ioyd91dT8YqvjKD_uMV'
url = f'https://drive.google.com/uc?id={file_id}'

# Download the file
gdown.download(url, 'data.csv', quiet=False)

# Read the CSV file into a DataFrame
hs12_df = pd.read_csv('data.csv')

# Display the first few rows
print(hs12_df.head())
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1-KectG9Ye8Zy-Ioyd91dT8YqvjKD_uMV
# To: /content/data.csv
# 100%|██████████| 2.69M/2.69M [00:00<00:00, 19.8MB/s]
#                          Transaction_ID           Country    Product  \
# 0  e3e70682-c209-4cac-a29f-6fbed82c07cd          Colombia   describe
# 1  f728b4fa-4248-4e3a-8a5d-2f346baa9455             Chile  president
# 2  eb1167b3-67a9-4378-bc65-c1e582e2e662            Turkey        far
# 3  f7c1bd87-4da5-4709-9471-3d60c8a70639  Christmas Island     agency
# 4  e443df78-9558-467f-9ba9-1faf7a024204           Finland     policy
#
#   Import_Export  Quantity    Value        Date     Category              Port  \
# 0        Export      1979  9506.57  07-12-2023    Machinery        Robertbury
# 1        Export      5763  7100.91  04-04-2023     Clothing          Shahport
# 2        Import      5740  2450.34  21-08-2024  Electronics  South Joshuatown
# ...

# %%
# Data Dimensions
print("The dimensions of the data is: ",hs12_df.shape)
# Out:
# The dimensions of the data is:  (15000, 16)

# %%
# Data Variable Type
hs12_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction_ID   15000 non-null  object
#  1   Country          15000 non-null  object
#  2   Product          15000 non-null  object
#  3   Import_Export    15000 non-null  object
#  4   Quantity         15000 non-null  int64
#  5   Value            15000 non-null  float64
#  6   Date             15000 non-null  object
#  7   Category         15000 non-null  object
#  8   Port             15000 non-null  object
#  9   Customs_Code     15000 non-null  int64
#  10  Weight           15000 non-null  float64
#  11  Shipping_Method  15000 non-null  object
#  12  Supplier         15000 non-null  object
#  13  Customer         15000 non-null  object
#  14  Invoice_Number   15000 non-null  int64
#  15  Payment_Terms    15000 non-null  object
# ...

# %%
# Bifurcating the Variables into Index, Categorical (Nominal, Ordinal) and Non-Categorical Variables

hs12_index_vars = ['Transaction_ID', 'Invoice_Number']
hs12_nominal_vars = ['Country', 'Product', 'Import_Export', 'Category', 'Port', 'Shipping_Method', 'Supplier', 'Customer', 'Customs_Code']
hs12_ordinal_vars = ['Payment_Terms']

hs12_cat_vars = hs12_nominal_vars + hs12_ordinal_vars
hs12_non_cat_vars = ['Quantity', 'Value', 'Weight']

# %% [markdown]
# ## **Taking a Unique Sample of 5001 Records**

# %%
hs12_sample = pd.DataFrame.sample(hs12_df, n=5001, random_state=55012 ,ignore_index=False)
# Displaying the Dimensions of Sample Data.
hs12_sample.shape
# Out:
# (5001, 16)

# %% [markdown]
# ## **Data Pre-Processing**

# %%
hs12_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5001 entries, 9103 to 7271
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction_ID   5001 non-null   object
#  1   Country          5001 non-null   object
#  2   Product          5001 non-null   object
#  3   Import_Export    5001 non-null   object
#  4   Quantity         5001 non-null   int64
#  5   Value            5001 non-null   float64
#  6   Date             5001 non-null   object
#  7   Category         5001 non-null   object
#  8   Port             5001 non-null   object
#  9   Customs_Code     5001 non-null   int64
#  10  Weight           5001 non-null   float64
#  11  Shipping_Method  5001 non-null   object
#  12  Supplier         5001 non-null   object
#  13  Customer         5001 non-null   object
#  14  Invoice_Number   5001 non-null   int64
#  15  Payment_Terms    5001 non-null   object
# dtypes: float64(2), int64(3), object(11)
# ...

# %%
# Check for missing values

hs12_sample.isnull().sum(axis=1)
# Out:
# 9103     0
# 12402    0
# 4244     0
# 9632     0
# 12936    0
#         ..
# 14034    0
# 4583     0
# 12001    0
# 615      0
# 7271     0
# Length: 5001, dtype: int64

# %% [markdown]
# **> Observation**: As the sum of the missing data column is 0, it is evident
# that there's no presence of missing data in the dataset. So the process of missing data treatment is skipped.

# %%
# Encoding

from sklearn.preprocessing import OrdinalEncoder  # Import the missing module

hs12_oe = OrdinalEncoder()
hs12_categorical_cols = hs12_sample[hs12_cat_vars]
hs12_oe_fit = hs12_oe.fit_transform(hs12_categorical_cols)
hs12_encoded = pd.DataFrame(hs12_oe_fit, columns=hs12_cat_vars)
hs12_encoded.head()
# Out:
#    Country  Product  Import_Export  Category    Port  Shipping_Method  \
# 0    170.0    229.0            1.0       0.0  1940.0              1.0
# 1     51.0    371.0            1.0       3.0  2483.0              1.0
# 2    126.0    162.0            1.0       1.0  2135.0              2.0
# 3    204.0    960.0            1.0       3.0  3469.0              0.0
# 4    172.0    362.0            1.0       3.0  3848.0              1.0
#
#    Supplier  Customer  Customs_Code  Payment_Terms
# 0    1690.0    2245.0        1828.0            0.0
# 1    3850.0    3202.0        4855.0            1.0
# 2    2719.0    2256.0        1687.0            2.0
# 3    1541.0    1682.0        3861.0            1.0
# 4    1096.0    4705.0        3931.0            0.0

# %%
#Scaling
from sklearn.preprocessing import MinMaxScaler # Import MinMaxScaler

hs12_scaler = MinMaxScaler()
hs12_scaled_data = hs12_scaler.fit_transform(hs12_sample[hs12_non_cat_vars])
hs12_scaled = pd.DataFrame(hs12_scaled_data, columns=hs12_non_cat_vars)
hs12_scaled.head()
# Out:
#    Quantity     Value    Weight
# 0  0.286730  0.349955  0.460324
# 1  0.880521  0.961082  0.019320
# 2  0.482023  0.995500  0.784045
# 3  0.815623  0.794577  0.399123
# 4  0.747021  0.117327  0.950154

# %%
hs12_processed = pd.concat([hs12_scaled, hs12_encoded], axis=1) # Replaced hs12 with hs12
hs12_processed.head()

hs12_sample = hs12_processed # Replaced hs12 with hs12
hs12_sample.head()
# Out:
#    Quantity     Value    Weight  Country  Product  Import_Export  Category  \
# 0  0.286730  0.349955  0.460324    170.0    229.0            1.0       0.0
# 1  0.880521  0.961082  0.019320     51.0    371.0            1.0       3.0
# 2  0.482023  0.995500  0.784045    126.0    162.0            1.0       1.0
# 3  0.815623  0.794577  0.399123    204.0    960.0            1.0       3.0
# 4  0.747021  0.117327  0.950154    172.0    362.0            1.0       3.0
#
#      Port  Shipping_Method  Supplier  Customer  Customs_Code  Payment_Terms
# 0  1940.0              1.0    1690.0    2245.0        1828.0            0.0
# 1  2483.0              1.0    3850.0    3202.0        4855.0            1.0
# 2  2135.0              2.0    2719.0    2256.0        1687.0            2.0
# 3  3469.0              0.0    1541.0    1682.0        3861.0            1.0
# 4  3848.0              1.0    1096.0    4705.0        3931.0            0.0

# %% [markdown]
# ## **Descriptive Statistics**
#
# ### **1. Non-Categorical Variables**

# %%
hs12_sample[hs12_non_cat_vars].describe() # Replace hs12 with hs12
# Out:
#           Quantity        Value       Weight
# count  5001.000000  5001.000000  5001.000000
# mean      0.499041     0.492812     0.499925
# std       0.289108     0.288125     0.290568
# min       0.000000     0.000000     0.000000
# 25%       0.246269     0.245259     0.250982
# 50%       0.500250     0.485770     0.495714
# 75%       0.752629     0.739466     0.755526
# max       1.000000     1.000000     1.000000

# %% [markdown]
# #### **> Observations:**
#
# **Central Tendency:** The mean values for Quantity, Value, and Weight are all centered around 0.5, indicating a balanced distribution after Min-Max scaling.
#
# **Similar Variability:** The standard deviation for all three variables is around 0.29, signifying moderate data dispersion.
#
# **Scaled Data:** The minimum and maximum values of 0 and 1 respectively confirm the data has been normalized using Min-Max scaling.

# %%
def summarize_numerical(my_sample, variables):
    summary = {}

    for col in variables:
        if col in hs12_sample[hs12_non_cat_vars]:  # Check if the column exists in the DataFrame
            summary[col] = {
                'Mode': my_sample[col].mode()[0],
                'Range': my_sample[col].max() - my_sample[col].min(),
                'Skewness': my_sample[col].skew() ,
                'Kurtosis': my_sample[col].kurtosis()
            }
    return summary

# %%
summary_stats = summarize_numerical(hs12_sample, hs12_non_cat_vars)
summary_df = pd.DataFrame.from_dict(summary_stats, orient='index')
summary_df
# Out:
#               Mode  Range  Skewness  Kurtosis
# Quantity  0.585578    1.0  0.015530 -1.211247
# Value     0.005074    1.0  0.046149 -1.186849
# Weight    0.004373    1.0  0.023058 -1.210857

# %%
summary_stats = summarize_numerical(hs12_sample, hs12_non_cat_vars) # Replace hs12 with hs12
summary_df = pd.DataFrame.from_dict(summary_stats, orient='index')
summary_df
# Out:
#               Mode  Range  Skewness  Kurtosis
# Quantity  0.585578    1.0  0.015530 -1.211247
# Value     0.005074    1.0  0.046149 -1.186849
# Weight    0.004373    1.0  0.023058 -1.210857

# %%
# In cell ipython-input-21-d1fb6ae70a08, replace all 'hs12_sample' with 'hs12_sample', and 'hs12_non_cat_vars' with 'hs12_non_cat_vars':

def summarize_numerical(my_sample, variables):
    summary = {}

    for col in variables:
        if col in hs12_sample
# Out:
#   File "<ipython-input-16-ca1a90de7281>", line 7
#     if col in hs12_sample
#                          ^
# SyntaxError: expected ':'

# %% [markdown]
# #### **> Observations:**
#
# **Range:**
# All three variables (Quantity, Value, Weight) exhibit a range of 1.0. This confirms that Min-Max scaling has effectively normalized the data to cover the entire range from 0 to 1, maximizing variability utilization.
#
# **Skewness:**
# Skewness values for Quantity, Value, and Weight are close to zero. This indicates near-symmetric distributions, suggesting a balanced frequency of observations on both sides of the average, with a potential slight positive skew.
#
# **Kurtosis:**
# Kurtosis values for all three variables are negative. This implies platykurtic distributions, meaning the data has fewer extreme values or outliers compared to a normal distribution, resulting in a flatter peak.

# %%
# Coefficient of Variation
def coefficient_of_variation(data):
    mean = data.mean()
    std = data.std()
    cv = (std / mean) * 100
    return cv

cv_results = {}

for col in hs12_non_cat_vars:
    cv_results[col] = coefficient_of_variation(hs12_sample[col])

# Display the results
print("Coefficient of Variation (%):")
for col, cv in cv_results.items():
    print(f"{col}: {cv:.2f}%")

# %% [markdown]
# ####**> Observations:**
#
# **Quantity:**
#
# - Quantity has a CV of 58.02%.
# - This indicates moderate variability or dispersion in the quantity of products traded relative to the mean quantity.
#
# **Value:**
#
# - Value shows a CV of 58.03%.
# - This suggests a moderate level of variability in the monetary value of transactions compared to the average transaction value.
#
# **Weight:**
#
# - Weight exhibits a CV of 58.38%.
# - This signifies moderate variability in the weight of products traded relative to the mean weight, potentially reflecting product diversity.

# %%
# Confidence Interval for the Mean
def confidence_interval(data, confidence=0.95):
    mean = data.mean()
    std = data.std()
    n = len(data)
    z = stats.norm.ppf(1 - (1 - confidence) / 2)  # z-score for 95% CI
    margin_of_error = z * (std / np.sqrt(n))
    lower_bound = mean - margin_of_error
    upper_bound = mean + margin_of_error
    return (lower_bound, upper_bound)

ci_results = {}
for col in hs12_non_cat_vars:
    ci_results[col] = confidence_interval(hs12_sample[col])


print("\nConfidence Intervals (95%):")
for col, ci in ci_results.items():
    print(f"{col}: {ci[0]:.2f} to {ci[1]:.2f}")
# Out:
# Confidence Intervals (95%):
# Quantity: 0.49 to 0.51
# Value: 0.48 to 0.50
# Weight: 0.49 to 0.51

# %% [markdown]
# ####**> Observations:**
#
# **Quantity:**
#
# - The 95% CI for Quantity is 0.49 to 0.51.
# - This narrow interval suggests high precision in estimating the true population mean of Quantity, indicating a likely centralized distribution around 0.5.
#
# **Value:**
#
# - The 95% CI for Value is 0.49 to 0.51.
# - This slightly wider interval compared to Quantity implies a marginally higher uncertainty in estimating the population mean of Value, but still indicates a relatively centralized distribution.
#
# **Weight:**
#
# - The 95% CI for Weight is 0.49 to 0.50.
# - Similar to Value, this interval reflects moderate certainty in estimating the population mean of Weight and a likely centralized distribution around 0.5.

# %%
correlation_data = hs12_sample[hs12_non_cat_vars]
correlation_matrix = correlation_data.corr()
print("Correlation Matrix:")
correlation_matrix
# Out:
# Correlation Matrix:
#           Quantity     Value    Weight
# Quantity  1.000000  0.008548  0.001284
# Value     0.008548  1.000000 -0.008044
# Weight    0.001284 -0.008044  1.000000

# %%
plt.figure(figsize=(8, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# ####**> Observations:**
#
# # Correlation Analysis: Quantity, Value, and Weight
#
# ## Correlation Coefficients
# 1. **Quantity vs. Value**:
#    - Correlation Coefficient: **-0.0022**
#    - **Interpretation**: Suggests a negligible negative relationship. This means that there's hardly any discernible pattern in how changes in quantity affect the value.
#
# 2. **Quantity vs. Weight**:
#    - Correlation Coefficient: **0.0028**
#    - **Interpretation**: Implies a negligible positive relationship. This means there's almost no consistent association between changes in quantity and weight.
#
# 3. **Value vs. Weight**:
#    - Correlation Coefficient: **-0.0078**
#    - **Interpretation**: Indicates a negligible negative relationship. This suggests that changes in value have little to no impact on weight.
#
# ---
#
# ## Implications
#
# ### 1. Independent Variables:
# - The weak correlations suggest that these variables are largely **independent of each other**.
# - **Insight**: Changes in one variable do not strongly predict changes in the others.
#
# ### 2. Further Analysis:
# - To gain deeper insights, it might be beneficial to:
#   - Explore **non-linear relationships**.
#   - Consider **additional variables** that could influence these relationships.

# %% [markdown]
# ### **2. Categorical Variables**

# %%
# Categorical Data

def hs12_categorical_summary(df, cat_cols):
    summary = {}
    for col in cat_cols:
        if col in df.columns:
            summary[col] = {
                'Count': df[col].count(),
                'Minimum': df[col].min(),
                'Maximum': df[col].max(),
                'Mode': df[col].mode().iloc[0],
            }
    return summary

hs12_categorical_summaries = hs12_categorical_summary(hs12_sample, hs12_cat_vars)

for col, stats in hs12_categorical_summaries.items():
    print(f"Summary for {col}:")
    for stat_name, stat_value in stats.items():
        print(f"  {stat_name}: {stat_value}")
    print("-" * 20)  # separator
# Out:
# Summary for Country:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 242.0
#   Mode: 49.0
# --------------------
# Summary for Product:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 962.0
#   Mode: 138.0
# --------------------
# Summary for Import_Export:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 1.0
#   Mode: 1.0
# --------------------
# Summary for Category:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 4.0
#   Mode: 1.0
# --------------------
# Summary for Port:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 4320.0
#   Mode: 4134.0
# --------------------
# Summary for Shipping_Method:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 2.0
#   Mode: 0.0
# --------------------
# Summary for Supplier:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 4560.0
#   Mode: 1967.0
# --------------------
# Summary for Customer:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 4844.0
#   Mode: 173.0
# --------------------
# Summary for Customs_Code:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 4992.0
# ...

# %% [markdown]
# ## **Data Visualization**

# %%
# Box plots for non-categorical variables

plt.figure(figsize=(15, 10))
for i, col in enumerate(hs12_non_cat_vars):
    plt.subplot(2, 3, i + 1)
    sns.boxplot(y=hs12_sample[col])
    plt.title(f'Box Plot of {col}')
plt.tight_layout()
plt.show()

# %%
# Histograms with KDE for distribution visualization
plt.figure(figsize=(15, 10))
for i, col in enumerate(hs12_non_cat_vars):
    plt.subplot(2, 3, i + 1)
    sns.histplot(hs12_sample[col], kde=True)
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# %%
# Violin Plot

sns.violinplot(x='Category', y='Quantity', data=hs12_sample)
plt.title('Distribution of Quantity across Categories')
plt.show()

# %% [markdown]
# ## **Inferential Statistics**

# %%
# Test of Homogeneity {Chi-sq} on categorical data

hs12_contingency_table = pd.crosstab(hs12_sample['Import_Export'], hs12_sample['Category'])

# Perform the Chi-square test
chi2, p, dof, expected = chi2_contingency(hs12_contingency_table)

print(f"Chi-square statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of freedom: {dof}")
print("Expected frequencies:")
print(expected)

# Interpret the results
hs12_alpha = 0.05  # Significance level

if p < hs12_alpha:
    print("Reject the null hypothesis: There is a significant association between the two categorical variables.")
else:
    print("There is no significant association between the two categorical variables.")
# Out:
# Chi-square statistic: 2.4364226358745387
# P-value: 0.6560553231952736
# Degrees of freedom: 4
# Expected frequencies:
# [[497.5764847  506.48830234 486.68426315 497.5764847  487.67446511]
#  [507.4235153  516.51169766 496.31573685 507.4235153  497.32553489]]
# There is no significant association between the two categorical variables.

# %%
# Test of Normality {Shapiro-Wilk | Kolmogorov-Smirnov | Anderson-Darling | Jarque-Bera

def normality_tests(data):

    hs12_results = {}

    # Shapiro-Wilk test
    shapiro_statistic, shapiro_pvalue = shapiro(data)
    hs12_results["Shapiro-Wilk"] = {"statistic": shapiro_statistic, "p-value": shapiro_pvalue}

    # Kolmogorov-Smirnov test (against a normal distribution)
    ks_statistic, ks_pvalue = kstest(data, 'norm')
    hs12_results["Kolmogorov-Smirnov"] = {"statistic": ks_statistic, "p-value": ks_pvalue}

    # Anderson-Darling test
    anderson_result = anderson(data)
    hs12_results["Anderson-Darling"] = {
        "statistic": anderson_result.statistic,
        "critical_values": anderson_result.critical_values,
        "significance_level": anderson_result.significance_level
    }

    # Jarque-Bera test
    jb_statistic, jb_pvalue = jarque_bera(data)
    hs12_results["Jarque-Bera"] = {"statistic": jb_statistic, "p-value": jb_pvalue}

    return hs12_results

# %%
from scipy import stats

# Test of Correlation (T-test)
def t_test_correlation(data1, data2):
    t_statistic, p_value = stats.ttest_ind(data1, data2)
    return {"t-statistic": t_statistic, "p-value": p_value}

for col in hs12_non_cat_vars:
    print(f"Normality tests for {col}:")
    normality_test_results = normality_tests(hs12_sample[col])
    for test_name, result in normality_test_results.items():
        print(f"  {test_name}: {result}")

    # Example of T-test
    if len(hs12_non_cat_vars) > 1:
        for i in range(len(hs12_non_cat_vars)):
            for j in range(i+1, len(hs12_non_cat_vars)):
                col1, col2 = hs12_non_cat_vars[i], hs12_non_cat_vars[j]
                t_test_result = t_test_correlation(hs12_sample[col1], hs12_sample[col2])
                print(f"T-test Correlation between {col1} and {col2}: {t_test_result}")
    print()
    print('*'*20)
    print()
# Out:
# Normality tests for Quantity:
#   Shapiro-Wilk: {'statistic': 0.9537607615926968, 'p-value': 4.047214666316646e-37}
#   Kolmogorov-Smirnov: {'statistic': 0.5, 'p-value': 0.0}
#   Anderson-Darling: {'statistic': 57.99407039646667, 'critical_values': array([0.576, 0.655, 0.786, 0.917, 1.091]), 'significance_level': array([15. , 10. ,  5. ,  2.5,  1. ])}
#   Jarque-Bera: {'statistic': 305.90625759353765, 'p-value': 3.7436925374374127e-67}
# T-test Correlation between Quantity and Value: {'t-statistic': 1.0791267983150523, 'p-value': 0.28055723374469776}
# T-test Correlation between Quantity and Weight: {'t-statistic': -0.15250687612477185, 'p-value': 0.8787902443093042}
# T-test Correlation between Value and Weight: {'t-statistic': -1.2291613384024689, 'p-value': 0.2190402427212853}
#
# ********************
#
# Normality tests for Value:
#   Shapiro-Wilk: {'statistic': 0.9555907285009617, 'p-value': 1.554459281827355e-36}
# ...

# %% [markdown]
# ## Observations:
#
# ### 1. Normality Tests for Quantity, Value, and Weight
#
# #### Shapiro-Wilk Test:
# - All three variables (`Quantity`, `Value`, `Weight`) have very low p-values (much smaller than 0.05).
# - **Conclusion**: The null hypothesis of normality is rejected for all three variables, indicating they are **not normally distributed**.
#
# #### Kolmogorov-Smirnov Test:
# - The `statistic` is 0.5 for `Quantity` and `Value`, and 0.5001 for `Weight`, with p-values of 0.0.
# - **Conclusion**: The null hypothesis of normality is also rejected here, confirming the non-normal distribution of the data.
#
# #### Anderson-Darling Test:
# - The `statistic` values for all variables (e.g., `Quantity`: 59.27, `Value`: 58.63, `Weight`: 54.37) far exceed the critical values at all significance levels.
# - **Conclusion**: This reinforces the finding that none of the variables follow a normal distribution.
#
# #### Jarque-Bera Test:
# - All p-values (e.g., `Quantity`: 9.17e-68, `Value`: 1.68e-67, `Weight`: 4.19e-65) are significantly smaller than 0.05.
# - **Conclusion**: The data is highly non-normal as per this test as well.
#
# ---
#
# ### 2. T-Test Correlations
#
# #### Quantity vs. Value:
# - **t-statistic**: -0.7054, **p-value**: 0.4806
# - **Interpretation**: No significant correlation between `Quantity` and `Value` as p-value > 0.05.
#
# #### Quantity vs. Weight:
# - **t-statistic**: 0.3022, **p-value**: 0.7625
# - **Interpretation**: No significant correlation between `Quantity` and `Weight` as p-value > 0.05.
#
# #### Value vs. Weight:
# - **t-statistic**: 1.0054, **p-value**: 0.3147
# - **Interpretation**: No significant correlation between `Value` and `Weight` as p-value > 0.05.
#
# ---
#
# ### Summary Observations:
#
# #### Non-Normality:
# - All variables (`Quantity`, `Value`, and `Weight`) exhibit strong evidence against normality across multiple tests (Shapiro-Wilk, Kolmogorov-Smirnov, Anderson-Darling, and Jarque-Bera).
#
# #### Weak Relationships:
# - The t-tests reveal no significant linear relationships between the pairs of variables (`Quantity`, `Value`, and `Weight`), as all p-values are well above the 0.05 threshold.
#
# #### Actionable Insights:
# - The absence of normality and significant correlations suggests:
#   - Consider using **non-parametric statistical methods** or **transformations** (e.g., log or Box-Cox) for further analysis.
#   - Explore potential **non-linear relationships** between variables.
#   - Additional variables may be needed to uncover meaningful patterns or associations.

# %% [markdown]
# #**Supervised Learning**

# %% [markdown]
# ### **Split into test and train dataset**

# %%
hs12_X = hs12_processed[['Quantity','Weight']]  # Features (excluding 'Cluster')
hs12_y = hs12_processed[['Shipping_Method']]  # Target variable

hs12_X_train, hs12_X_test, hs12_y_train, hs12_y_test = train_test_split(hs12_X, hs12_y, test_size=0.3, random_state=55024)

# Print the shapes of the resulting datasets
print("X_train shape:", hs12_X_train.shape)
print("X_test shape:", hs12_X_test.shape)
print("y_train shape:", hs12_y_train.shape)
print("y_test shape:", hs12_y_test.shape)
# Out:
# X_train shape: (3500, 2)
# X_test shape: (1501, 2)
# y_train shape: (3500, 1)
# y_test shape: (1501, 1)

# %% [markdown]
# ###**> Classification <**
#
# ###**Decision Tree**

# %%
# Initialize the Decision Tree Classifier
hs12_dt_classifier = DecisionTreeClassifier(criterion='gini', random_state=55024)

# Train the model
hs12_dt_classifier.fit(hs12_X_train, hs12_y_train)

# Make predictions on the test set
hs12_y_pred_dt = hs12_dt_classifier.predict(hs12_X_test)

# %%
# Evaluate the model
hs12_accuracy_dt = accuracy_score(hs12_y_test, hs12_y_pred_dt)
print(f"Decision Tree Accuracy: {hs12_accuracy_dt}")
print(classification_report(hs12_y_test, hs12_y_pred_dt))
# Out:
# Decision Tree Accuracy: 0.32978014656895405
#               precision    recall  f1-score   support
#
#          0.0       0.35      0.34      0.35       529
#          1.0       0.32      0.32      0.32       477
#          2.0       0.31      0.32      0.32       495
#
#     accuracy                           0.33      1501
#    macro avg       0.33      0.33      0.33      1501
# weighted avg       0.33      0.33      0.33      1501

# %% [markdown]
# ## Observations on Decision Tree Model Performance:
#
# ### Accuracy:
# - **Accuracy**: 0.3278
#   - The Decision Tree model's accuracy is approximately 32.78%, which is relatively low, indicating the model struggles to classify the data accurately.
#
# ---
#
# ### Classification Report:
# - **Class 0**:
#   - **Precision**: 0.32
#   - **Recall**: 0.30
#   - **F1-Score**: 0.31
#   - The model correctly identifies 30% of actual Class 0 instances.
#
# - **Class 1**:
#   - **Precision**: 0.33
#   - **Recall**: 0.35
#   - **F1-Score**: 0.34
#   - Slightly better performance for Class 1, with 35% of actual instances correctly classified.
#
# - **Class 2**:
#   - **Precision**: 0.33
#   - **Recall**: 0.34
#   - **F1-Score**: 0.33
#   - Performance is similar to Class 1 but still relatively poor.
#
# ---
#
# ### Averages:
# - **Macro Average**:
#   - **Precision**: 0.33
#   - **Recall**: 0.33
#   - **F1-Score**: 0.33
#   - Indicates the model's balanced performance across all classes.
#
# - **Weighted Average**:
#   - **Precision**: 0.33
#   - **Recall**: 0.33
#   - **F1-Score**: 0.33
#   - Reflects the performance, considering class imbalance (if any).
#
# ---
#
# ### Key Insights:
# 1. **Low Performance**:
#    - The overall accuracy (32.78%) and low precision, recall, and F1-scores across all classes indicate that the Decision Tree model is not performing well on this dataset.
#
# 2. **Class Similarity**:
#    - The performance metrics are nearly identical across all classes, suggesting that the model may not effectively differentiate between the classes.
#
# 3. **Potential Causes**:
#    - The dataset might be complex or noisy, making it challenging for a single Decision Tree to capture patterns.
#    - Features might not be strongly predictive of the target variable.
#    - There could be class imbalance, although not explicitly indicated in the support values.
#
# ---
#
# ### Recommendations:
# 1. **Feature Engineering**:
#    - Explore additional feature transformations or creation to enhance the predictive power of the input variables.
#
# 2. **Ensemble Methods**:
#    - Use ensemble models like Random Forest or Gradient Boosting to improve classification performance and handle complexity better.
#
# 3. **Hyperparameter Tuning**:
#    - Optimize the Decision Tree parameters (e.g., maximum depth, minimum samples per split) to potentially improve performance.
#
# 4. **Analyze Dataset**:
#    - Examine the data distribution, feature importance, and potential outliers to identify factors contributing to low performance.

# %%
# Confusion matrix

hs12_cm = confusion_matrix(hs12_y_test, hs12_y_pred_dt)

# Plot the confusion matrix using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(hs12_cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=hs12_dt_classifier.classes_, yticklabels=hs12_dt_classifier.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for Decision Tree')
plt.show()

# %% [markdown]
# ## Analysis of Confusion Matrix for Decision Tree
#
# ### Structure of the Matrix:
# - **Rows** represent the actual class labels.
# - **Columns** represent the predicted class labels.
# - The diagonal elements represent correct classifications for each class.
#
# ---
#
# ### Observations:
# 1. **Class 0**:
#    - **Correctly classified**: 153 instances
#    - **Misclassified as Class 1**: 171 instances
#    - **Misclassified as Class 2**: 185 instances
#    - The model struggles with Class 0, misclassifying the majority of instances into other classes.
#
# 2. **Class 1**:
#    - **Correctly classified**: 170 instances
#    - **Misclassified as Class 0**: 159 instances
#    - **Misclassified as Class 2**: 160 instances
#    - Performance for Class 1 is slightly better than Class 0 but still poor, with significant misclassifications.
#
# 3. **Class 2**:
#    - **Correctly classified**: 169 instances
#    - **Misclassified as Class 0**: 160 instances
#    - **Misclassified as Class 1**: 174 instances
#    - Similar performance as Class 1, with high misclassification rates.
#
# ---
#
# ### Overall Observations:
# - The model exhibits a **high level of confusion** between all three classes, with no class achieving high classification accuracy.
# - The **diagonal values (correct classifications)** are significantly outnumbered by the off-diagonal values (misclassifications), leading to low overall accuracy.
#
# ---
#
# ### Insights:
# 1. **Class Overlap**:
#    - The Decision Tree may not be effectively capturing the distinctions between the classes due to overlapping feature spaces or insufficient splitting criteria.
#
# 2. **Imbalance**:
#    - Misclassifications are relatively evenly distributed across classes, suggesting no significant class imbalance but a lack of separability.
#
# 3. **Model Limitations**:
#    - The simplicity of the Decision Tree algorithm might be contributing to its inability to model complex relationships in the data.
#
# ---
#
# ### Recommendations:
# 1. **Advanced Models**:
#    - Consider ensemble methods like **Random Forests** or **Gradient Boosting** to improve performance by combining multiple weak learners.
#
# 2. **Feature Engineering**:
#    - Perform detailed analysis to identify and create better features that improve class separability.
#
# 3. **Hyperparameter Optimization**:
#    - Experiment with tree depth, minimum samples per leaf, and splitting criteria to optimize performance.
#
# 4. **Dimensionality Reduction**:
#    - If the dataset has a high number of features, techniques like **PCA** or **t-SNE** could help reduce noise and improve performance.
#
# 5. **Data Augmentation**:
#    - Explore techniques to enhance the dataset and better represent the true data distribution.

# %% [markdown]
# ###**K Nearest Neighbours**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report


# 2. Create and train the KNN classifier
knn = KNeighborsClassifier(n_neighbors=5)  # You can adjust the number of neighbors (k)
knn.fit(hs12_X_train, hs12_y_train)

# 3. Make predictions on the test set
y_pred = knn.predict(hs12_X_test)

# 4. Evaluate the model
hs12_accuracy_knn = accuracy_score(hs12_y_test, y_pred)
print(f"Accuracy: {hs12_accuracy_knn}")
print(classification_report(hs12_y_test, y_pred))
# Out:
# Accuracy: 0.3384410393071286
#               precision    recall  f1-score   support
#
#          0.0       0.36      0.49      0.42       529
#          1.0       0.32      0.33      0.32       477
#          2.0       0.31      0.19      0.23       495
#
#     accuracy                           0.34      1501
#    macro avg       0.33      0.33      0.32      1501
# weighted avg       0.33      0.34      0.33      1501

# %% [markdown]
# ## Analysis of K-Nearest Neighbors (KNN) Classification Results
#
# ### Observations:
#
# 1. **Overall Accuracy**:
#    - The model achieved an **accuracy of 0.34** (33.78%).
#    - This is only marginally better than random guessing, indicating the model struggles to classify the data correctly.
#
# ---
#
# 2. **Class-Specific Performance**:
#    - **Class 0**:
#      - **Precision**: 0.33 (33%) - Out of all predictions for Class 0, 33% were correct.
#      - **Recall**: 0.41 (41%) - The model captured 41% of the actual Class 0 instances.
#      - **F1-Score**: 0.37 (37%) - Indicates a moderate balance between precision and recall for this class.
#    - **Class 1**:
#      - **Precision**: 0.33 (33%) - Out of all predictions for Class 1, 33% were correct.
#      - **Recall**: 0.35 (35%) - The model captured 35% of the actual Class 1 instances.
#      - **F1-Score**: 0.34 (34%) - Reflects low performance with slight improvement over Class 0.
#    - **Class 2**:
#      - **Precision**: 0.36 (36%) - Out of all predictions for Class 2, 36% were correct.
#      - **Recall**: 0.25 (25%) - The model captured only 25% of the actual Class 2 instances.
#      - **F1-Score**: 0.29 (29%) - Indicates poor performance for this class.
#
# ---
#
# 3. **Macro Average**:
#    - **Precision**: 0.34 (34%) - Average precision across all classes.
#    - **Recall**: 0.34 (34%) - Average recall across all classes.
#    - **F1-Score**: 0.33 (33%) - Average F1-score across all classes.
#    - The macro average confirms overall weak performance and difficulty in distinguishing between classes.
#
# ---
#
# 4. **Weighted Average**:
#    - **Precision**: 0.34 (34%) - Weighted precision considering the class support.
#    - **Recall**: 0.34 (34%) - Weighted recall considering the class support.
#    - **F1-Score**: 0.33 (33%) - Weighted F1-score across all classes.
#    - Reflects the overall model's inability to achieve good classification accuracy, even when considering class distributions.
#
# ---
#
# ### Insights and Implications:
#
# 1. **Low Accuracy**:
#    - The accuracy is low, indicating that the KNN algorithm, in its current configuration, is not well-suited for this dataset.
#
# 2. **Class Imbalance**:
#    - The F1-scores and recall values suggest the model struggles more with Class 2 compared to Class 0 and Class 1.
#
# 3. **Overlapping Features**:
#    - The low precision and recall indicate significant overlap between the feature distributions of the classes, making it challenging for KNN to distinguish between them.
#
# ---
#
# ### Recommendations:
#
# 1. **Hyperparameter Tuning**:
#    - Experiment with different values of `k` (number of neighbors) to find an optimal balance between bias and variance.
#    - Test different distance metrics (e.g., Euclidean, Manhattan, Minkowski) to better suit the dataset.
#
# 2. **Feature Scaling**:
#    - Ensure features are appropriately scaled (e.g., via Min-Max scaling or Standardization), as KNN is sensitive to feature magnitude.
#
# 3. **Dimensionality Reduction**:
#    - Apply techniques like **Principal Component Analysis (PCA)** to reduce noise and emphasize important features.
#
# 4. **Feature Selection**:
#    - Identify and use the most relevant features that contribute to class separability.
#
# 5. **Alternative Models**:
#    - Explore other algorithms like **Random Forests**, **Support Vector Machines (SVM)**, or **Neural Networks** that may perform better on this dataset.

# %% [markdown]
# ### **Naive Bayes (NB)**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB  # Or MultinomialNB, BernoulliNB
from sklearn.metrics import accuracy_score, classification_report

# 2. Create and train the Naive Bayes classifier
nb = GaussianNB()  # Choose the appropriate NB type (GaussianNB, MultinomialNB, BernoulliNB)
nb.fit(hs12_X_train, hs12_y_train)

# 3. Make predictions on the test set
hs12_y_pred = nb.predict(hs12_X_test)

# 4. Evaluate the model
hs12_accuracy_nb = accuracy_score(hs12_y_test, hs12_y_pred)
print(f"Accuracy: {hs12_accuracy_nb}")
print(classification_report(hs12_y_test, hs12_y_pred))
# Out:
# Accuracy: 0.3257828114590273
#               precision    recall  f1-score   support
#
#          0.0       0.34      0.76      0.47       529
#          1.0       0.29      0.16      0.20       477
#          2.0       0.25      0.03      0.05       495
#
#     accuracy                           0.33      1501
#    macro avg       0.29      0.31      0.24      1501
# weighted avg       0.29      0.33      0.25      1501

# %% [markdown]
# ## Naive Bayes Model Performance Analysis
#
# ### Overall Accuracy:
# - The model achieved an **accuracy of 0.33 (33%)**.
# - This means the model correctly predicted the class for 33% of the instances in the test dataset.
# - **Interpretation**: This is considered low accuracy, indicating poor performance in classifying the data.
#
# ---
#
# ### Class-wise Performance:
#
# #### Class 0.0:
# - **Precision**: 0.34 - Of all the instances predicted as Class 0.0, 34% were actually Class 0.0.
# - **Recall**: 0.18 - The model correctly identified only 18% of the actual Class 0.0 instances.
# - **F1-score**: 0.24 - Indicates a poor balance between precision and recall.
#
# #### Class 1.0:
# - **Precision**: 0.31 - Of all the instances predicted as Class 1.0, 31% were actually Class 1.0.
# - **Recall**: 0.27 - The model correctly identified only 27% of the actual Class 1.0 instances.
# - **F1-score**: 0.29 - Indicates a poor balance between precision and recall.
#
# #### Class 2.0:
# - **Precision**: 0.33 - Of all the instances predicted as Class 2.0, 33% were actually Class 2.0.
# - **Recall**: 0.52 - The model correctly identified 52% of the actual Class 2.0 instances.
# - **F1-score**: 0.40 - Indicates a slightly better balance between precision and recall for this class compared to others.
#
# ---
#
# ### Macro Average:
# - **Precision**: 0.33
# - **Recall**: 0.33
# - **F1-score**: 0.31
# - **Interpretation**: This average treats all classes equally, providing an overall view of the model's performance across all classes.
#
# ---
#
# ### Weighted Average:
# - **Precision**: 0.33
# - **Recall**: 0.33
# - **F1-score**: 0.31
# - **Interpretation**: This average weighs the class-wise metrics by the number of instances in each class, offering a more representative measure of the model's overall performance.
#
# ---
#
# ### Support:
# - **Class 0.0**: 509 instances
# - **Class 1.0**: 489 instances
# - **Class 2.0**: 503 instances
# - **Interpretation**: Indicates the number of samples in each class used for evaluation.
#
# ---
#
# ### Overall Observations:
# 1. **Low Accuracy**:
#    - The overall accuracy of 33% suggests the Naive Bayes model is not performing well on this dataset.
#
# 2. **Class Imbalance**:
#    - The model struggles with class imbalance, as reflected in the varying recall values across classes.
#    - **Class 2.0** shows a significantly higher recall compared to the other classes.
#
# 3. **Feature Independence Assumption**:
#    - Naive Bayes assumes feature independence, which might not hold true for this dataset, resulting in reduced performance.
#
# 4. **Further Investigation**:
#    - Exploring alternative classification algorithms and feature engineering techniques is recommended to improve performance.
#
# ---
#
# ### Recommendations:
# 1. **Explore Other Models**:
#    - Experiment with algorithms like **Decision Trees**, **Random Forests**, or **Support Vector Machines (SVM)**.
#
# 2. **Feature Engineering**:
#    - Create new features or transform existing ones to improve class separability.
#
# 3. **Address Class Imbalance**:
#    - Use techniques like **oversampling**, **undersampling**, or **cost-sensitive learning** to handle imbalanced datasets.
#
# 4. **Hyperparameter Tuning**:
#    - Fine-tune the Naive Bayes model's hyperparameters for potential performance improvements.
#
# 5. **Evaluate Feature Importance**:
#    - Identify influential features and improve their representation or quality.

# %% [markdown]
# ##**Logistic Regression**

# %%
# Initialize the Logistic Regression model
hs12_logreg_classifier = LogisticRegression(random_state=55024)

# Train the model
hs12_logreg_classifier.fit(hs12_X_train, hs12_y_train)

# Make predictions on the test set
hs12_y_pred_logreg = hs12_logreg_classifier.predict(hs12_X_test)

# Evaluate the model
hs12_accuracy_logreg = accuracy_score(hs12_y_test, hs12_y_pred_logreg)
print(f"Logistic Regression Accuracy: {hs12_accuracy_logreg}")
print(classification_report(hs12_y_test, hs12_y_pred_logreg))

# %% [markdown]
# ## Logistic Regression Model Performance Analysis
#
# ### Overall Accuracy:
# - The model achieved an **accuracy of 0.33 (33%)**.
# - This means the model correctly predicted the class for 33% of the instances in the test dataset.
# - **Interpretation**: This is considered low accuracy, indicating poor performance in classifying the data.
#
# ---
#
# ### Class-wise Performance:
#
# | **Class** | **Precision** | **Recall** | **F1-score** | **Support** |
# |-----------|---------------|------------|--------------|-------------|
# | **0.0**   | 0.33          | 0.17       | 0.23         | 509         |
# | **1.0**   | 0.32          | 0.32       | 0.32         | 489         |
# | **2.0**   | 0.33          | 0.49       | 0.39         | 503         |
#
# #### Interpretation:
# - **Precision**: Proportion of correctly predicted instances among all instances predicted as belonging to that class.
# - **Recall**: Proportion of correctly predicted instances among all actual instances of that class.
# - **F1-score**: Harmonic mean of precision and recall, providing a balanced measure of both.
#
# ---
#
# ### Macro Average:
# - **Precision**: 0.33
# - **Recall**: 0.33
# - **F1-score**: 0.31
# - **Interpretation**: Considers each class equally, providing an overall view of the model's performance across all classes.
#
# ---
#
# ### Weighted Average:
# - **Precision**: 0.33
# - **Recall**: 0.33
# - **F1-score**: 0.31
# - **Interpretation**: Weighs the class-wise metrics by the number of instances in each class, offering a more representative measure of the model's overall performance.
#
# ---
#
# ### Overall Observations:
# 1. **Low Accuracy**:
#    - The overall accuracy of 33% suggests the Logistic Regression model is not performing well on this dataset.
#
# 2. **Class Imbalance**:
#    - The model struggles with class imbalance, as indicated by the varying recall values across classes.
#    - **Class 2.0** shows a significantly higher recall compared to **Class 0.0**, which has a very low recall.
#
# 3. **Linearity Assumption**:
#    - Logistic Regression assumes a linear relationship between the features and the target variable.
#    - If the relationship is non-linear, the model's performance might be limited.
#
# 4. **Further Investigation**:
#    - Exploring alternative classification algorithms and feature engineering techniques is recommended to improve performance.
#
# ---
#
# ### Recommendations:
# 1. **Explore Other Models**:
#    - Experiment with algorithms like **Decision Trees**, **Random Forests**, or **Support Vector Machines (SVM)** to improve classification performance.
#
# 2. **Feature Engineering**:
#    - Create new features or transform existing ones to improve class separability.
#
# 3. **Address Class Imbalance**:
#    - Use techniques like **oversampling**, **undersampling**, or **cost-sensitive learning** to handle imbalanced datasets.
#
# 4. **Regularization**:
#    - Apply regularization techniques like **L1** or **L2 regularization** to prevent overfitting and improve generalization.
#
# 5. **Evaluate Feature Importance**:
#    - Identify influential features and improve their representation or quality.

# %%
# Confusion Matrix for Logistic Regression
cm_logreg = confusion_matrix(hs12_y_test, hs12_y_pred_logreg)

# Plot the confusion matrix for Logistic Regression
plt.figure(figsize=(8, 6))
sns.heatmap(cm_logreg, annot=True, fmt='d', cmap='Greens',  # Different colormap
            xticklabels=hs12_logreg_classifier.classes_, yticklabels=hs12_logreg_classifier.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for Logistic Regression')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-0de7076560d7> in <cell line: 2>()
#       1 # Confusion Matrix for Logistic Regression
# ----> 2 cm_logreg = confusion_matrix(hs12_y_test, hs12_y_pred_logreg)
#       3
#       4 # Plot the confusion matrix for Logistic Regression
#       5 plt.figure(figsize=(8, 6))
#
# NameError: name 'hs12_y_pred_logreg' is not defined

# %% [markdown]
# ## Confusion Matrix Analysis for Logistic Regression
#
# ### Observations:
# 1. **Class 0.0**:
#    - **True Positives (TP)**: 88 instances were correctly classified as Class 0.0.
#    - **False Negatives (FN)**: 421 instances (162 + 259) were misclassified as Class 1.0 or Class 2.0.
#    - **Key Insight**: The model struggles significantly in correctly predicting Class 0.0, with many instances being misclassified.
#
# 2. **Class 1.0**:
#    - **True Positives (TP)**: 157 instances were correctly classified as Class 1.0.
#    - **False Negatives (FN)**: 332 instances (93 + 239) were misclassified as Class 0.0 or Class 2.0.
#    - **Key Insight**: The performance for Class 1.0 is slightly better than Class 0.0, but a large number of instances are still misclassified.
#
# 3. **Class 2.0**:
#    - **True Positives (TP)**: 246 instances were correctly classified as Class 2.0.
#    - **False Negatives (FN)**: 257 instances (86 + 171) were misclassified as Class 0.0 or Class 1.0.
#    - **Key Insight**: The model performs comparatively better for Class 2.0, but there’s still room for improvement.
#
# 4. **General Trends**:
#    - The model has a bias towards predicting certain classes, as indicated by the higher number of false negatives for specific classes.
#    - Class 2.0 has the highest true positive count, indicating relatively better recall for this class.
#    - Class 0.0 and Class 1.0 have significantly lower true positive counts, suggesting the need for better differentiation of these classes.
#
# ---
#
# ### Recommendations to Improve Performance:
# 1. **Feature Engineering**:
#    - Create additional features that capture patterns or trends in the data to improve class separability.
#    - Perform feature scaling or transformation (e.g., Standardization or Normalization) to enhance model performance.
#
# 2. **Address Class Imbalance**:
#    - Use techniques like **SMOTE (Synthetic Minority Oversampling Technique)**, undersampling, or class weights to reduce the impact of class imbalance.
#
# 3. **Try Non-linear Models**:
#    - Experiment with non-linear models such as **Random Forests**, **Gradient Boosting (XGBoost, LightGBM)**, or **Neural Networks** to capture complex relationships in the data.
#
# 4. **Hyperparameter Tuning**:
#    - Perform grid search or random search to optimize hyperparameters of the Logistic Regression model.
#
# 5. **Regularization**:
#    - Adjust regularization parameters (e.g., L1, L2) to prevent overfitting and improve generalization.
#
# 6. **Cross-validation**:
#    - Use k-fold cross-validation to ensure robust evaluation and prevent overfitting to specific subsets of data.
#
# 7. **Visualize Features**:
#    - Analyze feature importance and their distributions to identify correlations and relationships between features and target classes.
#
# ---

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming hs12_sample is your DataFrame and 'Import_Export' is the target variable
# Replace 'Import_Export' with your actual target variable column name if different
hs12_X = hs12_sample.drop('Import_Export', axis=1)
hs12_y = hs12_sample['Import_Export']

# Split the data into training and testing sets
hs12_X_train, hs12_X_test, hs12_y_train, hs12_y_test = train_test_split(
    hs12_X, hs12_y, test_size=0.3, random_state=55024
)

# Initialize the Logistic Regression model
hs12_logreg_classifier = LogisticRegression(random_state=55024)

# Train the model
hs12_logreg_classifier.fit(hs12_X_train, hs12_y_train)

# Make predictions on the test set
hs12_y_pred_logreg = hs12_logreg_classifier.predict(hs12_X_test)

# Evaluate the model
hs12_accuracy_logreg = accuracy_score(hs12_y_test, hs12_y_pred_logreg)
print(f"Logistic Regression Accuracy: {hs12_accuracy_logreg}")
print(classification_report(hs12_y_test, hs12_y_pred_logreg))
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming hs12_sample is your DataFrame and 'Import_Export' is the target variable
# Replace 'Import_Export' with your actual target variable column name if different
hs12_X = hs12_sample.drop('Import_Export', axis=1)
hs12_y = hs12_sample['Import_Export']

# Split the data into training and testing sets
hs12_X_train, hs12_X_test, hs12_y_train, hs12_y_test = train_test_split(
    hs12_X, hs12_y, test_size=0.3, random_state=55024
)

# Initialize the Logistic Regression model
hs12_logreg_classifier = LogisticRegression(random_state=55024)

# Train the model
hs12_logreg_classifier.fit(hs12_X_train, hs12_y_train)

# Make predictions on the test set
hs12_y_pred_logreg = hs12_logreg_classifier.predict(hs12_X_test)

# Evaluate the model
hs12_accuracy_logreg = accuracy_score(hs12_y_test, hs12_y_pred_logreg)
print(f"Logistic Regression Accuracy: {hs12_accuracy_logreg}")
print(classification_report(hs12_y_test, hs12_y_pred_logreg))

# Confusion Matrix for Logistic Regression
cm_logreg = confusion_matrix(hs12_y_test, hs12_y_pred_logreg)
# Out:
# Logistic Regression Accuracy: 0.4996668887408394
#               precision    recall  f1-score   support
#
#          0.0       0.49      0.48      0.49       738
#          1.0       0.51      0.52      0.51       763
#
#     accuracy                           0.50      1501
#    macro avg       0.50      0.50      0.50      1501
# weighted avg       0.50      0.50      0.50      1501
#
# Logistic Regression Accuracy: 0.4996668887408394
#               precision    recall  f1-score   support
#
#          0.0       0.49      0.48      0.49       738
#          1.0       0.51      0.52      0.51       763
#
#     accuracy                           0.50      1501
#    macro avg       0.50      0.50      0.50      1501
# weighted avg       0.50      0.50      0.50      1501

# %% [markdown]
# ###**K-Fold Cross Validation for Logistic Regression**

# %%
# Initialize the Logistic Regression model
hs12_logreg_classifier = LogisticRegression(random_state=55024)

# Set up K-Fold Cross-Validation
kfold = KFold(n_splits=5, shuffle=True, random_state=55024)

# Perform Cross-Validation
cv_accuracy = cross_val_score(hs12_logreg_classifier, hs12_X_train, hs12_y_train, cv=kfold, scoring='accuracy')

# Output Cross-Validation results
print("K-Fold Cross-Validation Accuracy Scores: ", cv_accuracy)
print("Mean Accuracy: ", cv_accuracy.mean())
print("Standard Deviation of Accuracy: ", cv_accuracy.std())

# Train the model on the entire training set (if needed for later use)
hs12_logreg_classifier.fit(hs12_X_train, hs12_y_train)

# Evaluate the model on the test set
hs12_y_pred_logreg = hs12_logreg_classifier.predict(hs12_X_test)
hs12_accuracy_logreg = accuracy_score(hs12_y_test, hs12_y_pred_logreg)
print(f"Logistic Regression Test Set Accuracy: {hs12_accuracy_logreg}")
print(classification_report(hs12_y_test, hs12_y_pred_logreg))
# Out:
# K-Fold Cross-Validation Accuracy Scores:  [0.48142857 0.45857143 0.5        0.51285714 0.49428571]
# Mean Accuracy:  0.48942857142857144
# Standard Deviation of Accuracy:  0.01844130235783421
# Logistic Regression Test Set Accuracy: 0.4996668887408394
#               precision    recall  f1-score   support
#
#          0.0       0.49      0.48      0.49       738
#          1.0       0.51      0.52      0.51       763
#
#     accuracy                           0.50      1501
#    macro avg       0.50      0.50      0.50      1501
# weighted avg       0.50      0.50      0.50      1501

# %% [markdown]
# Observations:
#
# K-Fold Cross-Validation:
# * Accuracy Variability: The K-Fold Cross-Validation scores show some variability, ranging from 0.3329 to 0.3529. This indicates that the model's performance might fluctuate depending on the data folds used for training and validation.
# * Mean Accuracy: The mean accuracy of 0.3463 provides an overall estimate of the model's expected performance.
# * Standard Deviation: The standard deviation of 0.0074 indicates the variability of the accuracy scores across the folds. A higher standard deviation suggests that the model's performance is more sensitive to the specific data splits.
#
# Logistic Regression Test Set Accuracy:
# * Lower Test Accuracy: The test set accuracy of 0.3271 is slightly lower than the mean accuracy obtained through K-Fold Cross-Validation. This could be due to overfitting, where the model performs better on the training data (folds in cross-validation) than on unseen data (test set).
# * Class Imbalance: The precision, recall, and F1-score for each class are relatively low and imbalanced. This suggests that the model may not be effectively classifying all classes equally well.
#
# Overall:
# * Limited Performance: Both the cross-validation and test set accuracies are relatively low, indicating that the current model may not be performing well in classifying the target variable.
# * Potential for Improvement: The variability in cross-validation scores and the lower test set accuracy suggest that the model might benefit from further tuning, feature engineering, or exploring alternative models.
# """)

# %% [markdown]
# ###**K-Fold Cross Validation for Support Vector Machine (SVM)**

# %%
from sklearn.svm import SVC
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import classification_report, accuracy_score

# Initialize the SVM model
hs12_svm_classifier = SVC(kernel='linear', random_state=55024)

# Set up K-Fold Cross-Validation
kfold = KFold(n_splits=5, shuffle=True, random_state=55024)

# Perform Cross-Validation
cv_accuracy = cross_val_score(hs12_svm_classifier, hs12_X_train, hs12_y_train, cv=kfold, scoring='accuracy')

# Output Cross-Validation results
print("K-Fold Cross-Validation Accuracy Scores: ", cv_accuracy)
print("Mean Accuracy: ", cv_accuracy.mean())
print("Standard Deviation of Accuracy: ", cv_accuracy.std())

# Train the model on the entire training set (if needed for later use)
hs12_svm_classifier.fit(hs12_X_train, hs12_y_train)

# Evaluate the model on the test set
hs12_y_pred_svm = hs12_svm_classifier.predict(hs12_X_test)
hs12_accuracy_svm = accuracy_score(hs12_y_test, hs12_y_pred_svm)
print(f"SVM Test Set Accuracy: {hs12_accuracy_svm}")
print(classification_report(hs12_y_test, hs12_y_pred_svm))

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.svm import SVC  # Import the correct SVC class
from sklearn.metrics import accuracy_score
# ... (other imports)

# ... (Data preprocessing, encoding, and scaling as before)

# Split the data
hs12_X_train, hs12_X_test, hs12_y_train, hs12_y_test = train_test_split(
    hs12_X

# %% [markdown]
# **Observations**
#
# **K-Fold Cross-Validation:**
# * Consistent Accuracy: The cross-validation accuracy scores across the 5 folds are relatively consistent, ranging from 0.3386 to 0.3486. This suggests that the model's performance is stable and not overly sensitive to the specific data split.
# * Moderate Accuracy: The mean accuracy of 0.3434 indicates that the model is achieving a moderate level of accuracy in classifying the data during cross-validation. However, this accuracy is still relatively low, implying room for improvement.
# * Low Standard Deviation: The standard deviation of accuracy (0.0043) is quite low, further reinforcing the stability and consistency of the model's performance across different folds.
#
# **SVM Test Set Performance:**
# * Low Overall Accuracy: The test set accuracy of 0.3324 is similar to the cross-validation accuracy, indicating that the model is generalizing reasonably well to unseen data. However, the accuracy is still relatively low, suggesting that the model might not be effectively capturing the underlying patterns in the data.
#
# **Class-wise Performance:**
# * Class 0.0: The model completely fails to predict this class, with 0 precision, recall, and F1-score. This is a major concern and indicates a significant weakness of the model for this specific class.
# * Class 1.0 and 2.0: The model shows similar performance for these classes, with moderate precision, recall, and F1-score around 0.33-0.50. This suggests that the model might be better at distinguishing between these two classes compared to Class 0.0.
# * Macro and Weighted Averages: The macro and weighted average scores are relatively low, reflecting the overall poor performance of the model, particularly for Class 0.0.
#
# **Overall Interpretation:**
# * Model Limitations: The SVM model, with the current configuration and features, is not performing well in classifying the data, especially for Class 0.0.
#
# **Potential Issues:**
# * The poor performance for Class 0.0 might be due to several factors:
#     * Class Imbalance: If Class 0.0 has significantly fewer instances than other classes, the model might be biased towards the majority classes.
#     * Feature Relevance: The features used might not be informative enough to distinguish Class 0.0 from other classes.
#     * Model Complexity: The SVM model might be too complex or too simple for the given dataset, leading to overfitting or underfitting.
#
# **Further Investigation:**
# * It's crucial to investigate the reasons for the poor performance and explore potential solutions:
#     * Addressing Class Imbalance: Consider techniques like oversampling, undersampling, or using cost-sensitive learning to handle class imbalance.
#     * Feature Engineering: Explore new features or transformations of existing features that might better separate the classes.
#     * Hyperparameter Tuning: Optimize the SVM model's hyperparameters to potentially improve its performance.
#     * Alternative Models: Evaluate other classification algorithms to see if they provide better results for this dataset.

# %% [markdown]
# ###**K-Fold Cross Validation for Stochastic Gradient Descent (SGD)**

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import KFold, cross_val_score

# 1. Initialize the SGD Classifier
hs12_sgd_classifier = SGDClassifier(loss='log_loss', random_state=5045, max_iter=1000, tol=1e-3)
# Changed 'log' to 'log_loss' for logistic regression

# 2. Set up K-Fold Cross-Validation
kfold = KFold(n_splits=5, shuffle=True, random_state=55024)

# 3. Perform Cross-Validation
cv_accuracy = cross_val_score(hs12_sgd_classifier, hs12_X_train, hs12_y_train, cv=kfold, scoring='accuracy')

# 4. Output Cross-Validation Results
print("K-Fold Cross-Validation Accuracy Scores: ", cv_accuracy)
print("Mean Accuracy: ", cv_accuracy.mean())
print("Standard Deviation of Accuracy: ", cv_accuracy.std())

# 5. Train the SGD Classifier on the entire training set
hs12_sgd_classifier.fit(hs12_X_train, hs12_y_train)

# 6. Make predictions on the test set
hs12_y_pred_sgd = hs12_sgd_classifier.predict(hs12_X_test)

# 7. Evaluate the Model
hs12_accuracy_sgd = accuracy_score(hs12_y_test, hs12_y_pred_sgd)
print(f"SGD Test Set Accuracy: {hs12_accuracy_sgd}")
print(classification_report(hs12_y_test, hs12_y_pred_sgd))

# %% [markdown]
# **Observations**
#
# **K-Fold Cross-Validation:**
# * Accuracy Variation: The cross-validation accuracy scores across the 5 folds show some variation, ranging from 0.3171 to 0.3614. This suggests that the model's performance might be somewhat sensitive to the specific data split used in each fold.
# * Moderate Accuracy: The mean accuracy of 0.3383 indicates that the model is achieving a moderate level of accuracy in classifying the data during cross-validation. However, this accuracy is still relatively low, implying room for improvement.
# * Moderate Standard Deviation: The standard deviation of accuracy (0.0164) is moderate, reflecting the variability in the model's performance across different folds. This suggests that the model's performance might not be as stable as desired.
#
# **SGD Test Set Performance:**
# * Low Overall Accuracy: The test set accuracy of 0.3411 is similar to the cross-validation accuracy, indicating that the model is generalizing reasonably well to unseen data. However, the accuracy is still relatively low, suggesting that the model might not be effectively capturing the underlying patterns in the data.
#
# **Class-wise Performance:**
# * Class 0.0: The model shows high recall (0.95) for this class, meaning it correctly identifies most of the actual Class 0.0 instances. However, the precision is relatively low (0.34), indicating that many instances predicted as Class 0.0 are actually from other classes.
# * Class 1.0: The model completely fails to predict this class, with 0 precision, recall, and F1-score. This is a major concern and indicates a significant weakness of the model for this specific class.
# * Class 2.0: The model has very low recall (0.05) for this class, meaning it misses most of the actual Class 2.0 instances. The precision is moderate (0.41), indicating that when it does predict Class 2.0, it's often correct. However, the overall performance for this class is poor.
# * Macro and Weighted Averages: The macro and weighted average scores are relatively low, reflecting the overall poor performance of the model, particularly for Class 1.0 and 2.0.
#
# **Overall Interpretation:**
# * Model Limitations: The SGD model, with the current configuration and features, is not performing well in classifying the data, especially for Class 1.0 and 2.0. It seems to be biased towards Class 0.0, achieving high recall but low precision for that class.
#
# **Potential Issues:**
# * The poor performance might be due to several factors:
#     * Class Imbalance: Class imbalance could be affecting the model's ability to learn patterns for the minority classes.
#     * Feature Relevance: The features used might not be informative enough to distinguish between the classes effectively.
#     * Model Complexity: The SGD model's complexity might need adjustment to avoid overfitting or underfitting.
#     * Learning Rate and Iterations: The learning rate and number of iterations used during training might need optimization.

# %% [markdown]
# ###**Comparison of LR vs SVM**

# %%
print(f"Logistic Regression Accuracy: {hs12_accuracy_logreg}")
print(f"SVM Accuracy: {hs12_accuracy_svm}")

if hs12_accuracy_logreg > hs12_accuracy_svm:
    print("Logistic Regression model performs better.")
elif hs12_accuracy_svm > hs12_accuracy_logreg:
    print("Support Vector Machine model performs better.")
else:
    print("Both models perform equally.")

# %% [markdown]
# ###**Comparison of LR vs SGD**

# %%
print(f"Logistic Regression Accuracy: {hs12_accuracy_logreg}")
print(f"SGD Accuracy: {hs12_accuracy_sgd}")

if hs12_accuracy_logreg > hs12_accuracy_sgd:
    print("Logistic Regression model performs better.")
elif hs12_accuracy_sgd > hs12_accuracy_logreg:
    print("Stochastic Gradient Descent model performs better.")
else:
    print("Both models perform equally.")

# %% [markdown]
# ###**Comparison of DT vs KNN**

# %%
print(f"Decision Tree Accuracy: {hs12_accuracy_dt}")
print(f"KNN Accuracy: {hs12_accuracy_knn}")

if hs12_accuracy_dt > hs12_accuracy_knn:
    print("Decision Tree model performs better.")
elif hs12_accuracy_knn > hs12_accuracy_dt:
    print("K Nearest Neighbour model performs better.")
else:
    print("Both models perform equally.")

# %% [markdown]
# ###**Comparison of LR vs DT**

# %%
print(f"Logistic Regression Accuracy: {hs12_accuracy_logreg}")
print(f"Decision Tree Accuracy: {hs12_accuracy_dt}")

if hs12_accuracy_logreg > hs12_accuracy_dt:
    print("Logistic Regression model performs better.")
elif hs12_accuracy_dt > hs12_accuracy_logreg:
    print("Decision Tree model performs better.")
else:
    print("Both models perform equally.")

# %% [markdown]
# ###**Comparison of DT vs NB**

# %%
print(f"Decision Tree Accuracy: {hs12_accuracy_dt}")
print(f"Naive Bayes Accuracy: {hs12_accuracy_nb}")

if hs12_accuracy_dt > hs12_accuracy_nb:
    print("Decision Tree model performs better.")
elif hs12_accuracy_nb > hs12_accuracy_dt:
    print("Naive Bayes model performs better.")
else:
    print("Both models perform equally.")

# %% [markdown]
# ##**Random Forest**

# %%
# Initialize the Random Forest Classifier
hs12_rf_classifier = RandomForestClassifier(random_state=5024)

# Train the model
hs12_rf_classifier.fit(hs12_X_train, hs12_y_train)

# Make predictions on the test set
hs12_y_pred_rf = hs12_rf_classifier.predict(hs12_X_test)

# Evaluate the model
hs12_accuracy_rf = accuracy_score(hs12_y_test, hs12_y_pred_rf)
print(f"Random Forest Accuracy: {hs12_accuracy_rf}")
print(classification_report(hs12_y_test, hs12_y_pred_rf))

# %%
# Confusion Matrix for Random Forest
hs12_cm_rf = confusion_matrix(hs12_y_test, hs12_y_pred_rf)

# Plot the confusion matrix for Random Forest
plt.figure(figsize=(8, 6))
sns.heatmap(hs12_cm_rf, annot=True, fmt='d', cmap='Oranges',  # Different colormap
            xticklabels=hs12_rf_classifier.classes_, yticklabels=hs12_rf_classifier.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for Random Forest')
plt.show()

# %% [markdown]
# **Confusion Matrix Analysis for Random Forest**
#
# **Observations:**
#
# * **Class 0.0:** The model seems to be reasonably good at predicting Class 0.0, with 155 true positives and a relatively low number of false positives (172 and 182 for Classes 1.0 and 2.0, respectively).
# * **Class 1.0:** The model struggles to predict Class 1.0 accurately. There are a high number of false negatives (174) and false positives (175 and 140 for Classes 0.0 and 2.0, respectively).
# * **Class 2.0:** The model also has difficulty predicting Class 2.0. While it has a relatively high number of true positives (179), there are also a significant number of false negatives (159) and false positives (165 and 140 for Classes 0.0 and 1.0, respectively).
#
# **Overall:**
#
# * The Random Forest model appears to have some challenges in accurately classifying all three classes.
# * Class 0.0 seems to be the most accurately predicted class, while Classes 1.0 and 2.0 have higher rates of misclassification.
#
# **Possible Interpretations:**
#
# * **Class Imbalance:** If there's a significant class imbalance in the dataset, the model might be biased towards the majority class.
# * **Feature Relevance:** The features used in the model might not be sufficient to effectively distinguish between the different classes.
# * **Hyperparameter Tuning:** The hyperparameters of the Random Forest model (e.g., number of trees, maximum depth) might not be optimally tuned.
#
# **Recommendations:**
#
# * **Investigate Class Imbalance:** Check for class imbalance and consider techniques like oversampling, undersampling, or using class weights to address it.
# * **Feature Engineering:** Explore new features or transformations of existing features that might improve class separation.
# * **Hyperparameter Tuning:** Perform hyperparameter tuning to find the best combination of parameters for the Random Forest model.
# * **Consider Alternative Models:** Explore other classification algorithms, such as Support Vector Machines (SVM), XGBoost, or deep learning models, to see if they can achieve better performance.
#
# **Further Analysis:**
#
# * Calculate precision, recall, F1-score, and other relevant metrics to get a more quantitative understanding of the model's performance for each class.
# * Visualize the feature importance to identify the most influential features for classification.

# %% [markdown]
# ###**Extreme Gradient Boosting**

# %%
hs12_clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,
    max_depth=1, random_state=0).fit(hs12_X_train, hs12_y_train)
print("The mean accuracy on the given test data and labels from Extreme Gradient Boosting is",hs12_clf.score(hs12_X_test, hs12_y_test))

# %% [markdown]
# **Observation:**
#
# The mean accuracy of 0.3298 (rounded to four decimal places) suggests that the XGBoost model, on average, correctly classifies approximately 32.98% of the instances in the given test data. This accuracy level is relatively low, indicating limitations in the model's ability to accurately predict the target variable for this specific dataset and task.

# %% [markdown]
# ###**Comparison of RF vs DT**

# %%
# Compare Random Forest and Decision Tree

print(f"\nDecision Tree Accuracy: {hs12_accuracy_dt}")
print(f"Random Forest Accuracy: {hs12_accuracy_rf}")

if hs12_accuracy_rf > hs12_accuracy_dt:
    print("Random Forest performs better than Decision Tree.")
elif hs12_accuracy_dt > hs12_accuracy_rf:
    print("Decision Tree performs better than Random Forest.")
else:
    print("Both models perform equally.")

# %% [markdown]
# #Model Run Statistics

# %% [markdown]
# ##Time Taken

# %%
import time
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

def time_model_run(model, X_train, y_train):
    start_time = time.time()
    model.fit(X_train, y_train)
    end_time = time.time()
    return end_time - start_time

# Logistic Regression
log_reg_model = LogisticRegression(random_state=55024)
log_reg_time = time_model_run(log_reg_model, hs12_X_train, hs12_y_train)
print(f"Logistic Regression runtime: {log_reg_time:.4f} seconds")

# Support Vector Machine (SVM)
svm_model = SVC(random_state=55024)
svm_time = time_model_run(svm_model, hs12_X_train, hs12_y_train)
print(f"SVM runtime: {svm_time:.4f} seconds")

# Stochastic Gradient Descent (SGD)
sgd_model = SGDClassifier(random_state=55024)
sgd_time = time_model_run(sgd_model, hs12_X_train, hs12_y_train)
print(f"SGD runtime: {sgd_time:.4f} seconds")

# Decision Tree
dt_model = DecisionTreeClassifier(random_state=55024)
dt_time = time_model_run(dt_model, hs12_X_train, hs12_y_train)
print(f"Decision Tree runtime: {dt_time:.4f} seconds")

# K-Nearest Neighbors (KNN)
knn_model = KNeighborsClassifier(n_neighbors=5)
knn_time = time_model_run(knn_model, hs12_X_train, hs12_y_train)
print(f"KNN runtime: {knn_time:.4f} seconds")

# Naive Bayes
nb_model = GaussianNB()
nb_time = time_model_run(nb_model, hs12_X_train, hs12_y_train)
print(f"Naive Bayes runtime: {nb_time:.4f} seconds")

# Random Forest
rf_model = RandomForestClassifier(random_state=55024)
rf_time = time_model_run(rf_model, hs12_X_train, hs12_y_train)
print(f"Random Forest runtime: {rf_time:.4f} seconds")

# Extreme Gradient Boosting (XGBoost)
xgb_model = XGBClassifier(random_state=55024)
xgb_time = time_model_run(xgb_model, hs12_X_train, hs12_y_train)
print(f"XGBoost runtime: {xgb_time:.4f} seconds")

# %% [markdown]
# ---

# %% [markdown]
# **Runtime Observations:**
#
# * **Fastest Models:** KNN and Naive Bayes are the fastest models, with runtimes under 0.01 seconds.
# * **Moderate Runtime:** Logistic Regression, SGD, and Decision Tree have moderate runtimes, ranging from 0.0191 to 0.0317 seconds.
# * **Slower Models:** SVM and XGBoost have significantly longer runtimes, with SVM taking 0.5507 seconds and XGBoost taking 0.2515 seconds.
# * **Slowest Model:** Random Forest is the slowest model with a runtime of 1.0214 seconds.
#
# **Implications:**
#
# * For time-sensitive applications, KNN and Naive Bayes might be preferred due to their very fast execution times.
# * If computational cost is not a major concern, models like SVM, XGBoost, and Random Forest, which often provide higher accuracy, can be considered.
# * The choice of model should be based on a trade-off between computational cost and desired accuracy.
#
# **Note:** These runtime observations are specific to the current implementation and dataset. Runtimes can vary depending on factors like data size, model complexity, and hardware specifications.

# %% [markdown]
# ##Memory Utilized

# %%
import tracemalloc
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

def get_model_memory_usage(model, X, y):
    tracemalloc.start()
    model.fit(X, y)
    current, peak = tracemalloc.get_traced_memory()
    tracemalloc.stop()
    return peak / (1024 * 1024)  # Convert bytes to MB

# Logistic Regression
log_reg_model = LogisticRegression(random_state=55024)
log_reg_memory = get_model_memory_usage(log_reg_model, hs12_X_train, hs12_y_train)
print(f"Logistic Regression memory usage: {log_reg_memory:.2f} MB")

# Support Vector Machine (SVM)
svm_model = SVC(random_state=55024)
svm_memory = get_model_memory_usage(svm_model, hs12_X_train, hs12_y_train)
print(f"SVM memory usage: {svm_memory:.2f} MB")

# Stochastic Gradient Descent (SGD)
sgd_model = SGDClassifier(random_state=55024)
sgd_memory = get_model_memory_usage(sgd_model, hs12_X_train, hs12_y_train)
print(f"SGD memory usage: {sgd_memory:.2f} MB")

# Decision Tree
dt_model = DecisionTreeClassifier(random_state=55024)
dt_memory = get_model_memory_usage(dt_model, hs12_X_train, hs12_y_train)
print(f"Decision Tree memory usage: {dt_memory:.2f} MB")

# K-Nearest Neighbors (KNN)
knn_model = KNeighborsClassifier(n_neighbors=5)
knn_memory = get_model_memory_usage(knn_model, hs12_X_train, hs12_y_train)
print(f"KNN memory usage: {knn_memory:.2f} MB")

# Naive Bayes
nb_model = GaussianNB()
nb_memory = get_model_memory_usage(nb_model, hs12_X_train, hs12_y_train)
print(f"Naive Bayes memory usage: {nb_memory:.2f} MB")

# Random Forest
rf_model = RandomForestClassifier(random_state=55024)
rf_memory = get_model_memory_usage(rf_model, hs12_X_train, hs12_y_train)
print(f"Random Forest memory usage: {rf_memory:.2f} MB")

# Extreme Gradient Boosting (XGBoost)
xgb_model = XGBClassifier(random_state=55024)
xgb_memory = get_model_memory_usage(xgb_model, hs12_X_train, hs12_y_train)
print(f"XGBoost memory usage: {xgb_memory:.2f} MB")

# %% [markdown]
# **Memory Usage Observations**
#
# * **Naive Bayes:** Has the lowest memory usage at 0.11 MB, making it a lightweight option for memory-constrained environments.
# * **SGD:** Also has low memory usage (0.17 MB), making it a good choice for models with limited memory resources.
# * **Logistic Regression, SVM, Decision Tree, and KNN:** These models have moderate memory usage, ranging from 0.22 MB to 0.28 MB.
# * **Random Forest:** Has a higher memory usage (0.67 MB) compared to the other models. This is expected as Random Forest models typically require more memory to store multiple decision trees.
# * **XGBoost:** Has the highest memory usage (0.88 MB) among the models listed, likely due to its complex tree-based structure and the need to store model parameters for each tree.
#
# **Overall:**
#
# * Naive Bayes and SGD appear to be the most memory-efficient models in this comparison.
# * If memory usage is a critical factor, these models or other linear models (like Logistic Regression) could be preferred.
# * For more complex models like Random Forest and XGBoost, memory usage might increase significantly with larger datasets or deeper models.
#
# **Note:** These observations are based on the provided memory usage values for a specific implementation and dataset. Memory usage can vary depending on factors such as dataset size, model complexity, and implementation details.
